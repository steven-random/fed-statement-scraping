# %%
import pandas as pd

# %%
df = pd.read_csv('communications.csv')

# %%
df.sort_index()
# Out:
#            Date Release Date       Type  \
# 0    2025-01-29   2025-01-29  Statement
# 1    2024-12-18   2024-12-18  Statement
# 2    2024-12-18   2025-01-08     Minute
# 3    2024-11-07   2024-11-26     Minute
# 4    2024-11-07   2024-11-07  Statement
# ..          ...          ...        ...
# 438  2000-05-16   2000-05-16  Statement
# 439  2000-03-21   2000-05-18     Minute
# 440  2000-03-21   2000-03-21  Statement
# 441  2000-02-02   2000-03-23     Minute
# 442  2000-02-02   2000-02-02  Statement
#
#                                                   Text
# 0    Recent indicators suggest that economic activi...
# 1    Recent indicators suggest that economic activi...
# 2    Minutes of the Federal Open Market Committee\n...
# 3    Minutes of the Federal Open Market Committee\n...
# 4    Recent indicators suggest that economic activi...
# ..                                                 ...
# 438  The Federal Open Market Committee voted today ...
# ...
